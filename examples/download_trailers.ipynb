# %% [markdown]
# <a href="https://colab.research.google.com/github/RecSys-lab/MoViFex/blob/main/examples/download_trailers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MoViFex Framework - Trailer Downloader for `MoViFex` Dataset**
#
# 🎬 Dataset MoViFex Dataset: [link](https://huggingface.co/datasets/alitourani/MoViFex_Dataset/tree/main)
#
# 🎬 Framework: [link](https://github.com/RecSys-lab/MoViFex)

# %% [markdown]
# # [Step 1] - Load the Framework
#
# Clone the framework into your `GDrive` and prepare it for experiments.

# %%
# Clone the repo
# !git clone https://github.com/RecSys-lab/MoViFex.git

# Install the required library
# %cd MoViFex
# !pip install -e .

# Add the repository to the Python path
import sys
sys.path.append('/content/MoViFex')
# Out:
# Cloning into 'MoViFex'...
# remote: Enumerating objects: 710, done.
# remote: Counting objects: 100% (286/286), done.
# remote: Compressing objects: 100% (195/195), done.
# remote: Total 710 (delta 144), reused 213 (delta 85), pack-reused 424 (from 1)
# Receiving objects: 100% (710/710), 227.83 KiB | 4.65 MiB/s, done.
# Resolving deltas: 100% (361/361), done.
# /content/MoViFex
# Obtaining file:///content/MoViFex
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (2.2.2)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (1.26.4)
# Requirement already satisfied: opencv-python>=4.9 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (4.10.0.84)
# Requirement already satisfied: matplotlib>=3.9 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (3.10.0)
# Collecting pytube>=15.0 (from MoViFex==1.0.0)
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting scipy>=1.14.1 (from MoViFex==1.0.0)
#   Downloading scipy-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.32 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (2.32.3)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (6.0.2)
# Requirement already satisfied: tensorflow>=2.17.0 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (2.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->MoViFex==1.0.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->MoViFex==1.0.0) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->MoViFex==1.0.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->MoViFex==1.0.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->MoViFex==1.0.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->MoViFex==1.0.0) (2024.12.14)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (4.25.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.17.0->MoViFex==1.0.0) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow>=2.17.0->MoViFex==1.0.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow>=2.17.0->MoViFex==1.0.0) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow>=2.17.0->MoViFex==1.0.0) (0.13.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.17.0->MoViFex==1.0.0) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.17.0->MoViFex==1.0.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.17.0->MoViFex==1.0.0) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow>=2.17.0->MoViFex==1.0.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow>=2.17.0->MoViFex==1.0.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow>=2.17.0->MoViFex==1.0.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow>=2.17.0->MoViFex==1.0.0) (0.1.2)
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.9 MB/s eta 0:00:00
# Downloading scipy-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 MB 18.8 MB/s eta 0:00:00
# Installing collected packages: scipy, pytube, MoViFex
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Running setup.py develop for MoViFex
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.1 which is incompatible.
# Successfully installed MoViFex-1.0.0 pytube-15.0.0 scipy-1.15.1

# %% [markdown]
# # [Step 2] - Use the Framework 🚀
#
# Import the framework and define some variables to work with it.

# %%
import os
import json
import movifex

# Similar to the `config.yml` file in the framework - section `datasets/visual_dataset/movifex`
configs = {
    "pipelines": {
        "movie_trailers": {
            "name": "Trailer-fetcher",
            "download_path": "/"
        }
    },
    "datasets": {
        "visual_dataset":{
            "movifex": {
                "name": "MoViFex-visual",
                "path_metadata": "https://huggingface.co/datasets/alitourani/MoViFex_Dataset/resolve/main/stats.json"
            }
        }
    }
}

# Variables
cfgPipeline = configs['pipelines']['movie_trailers']
cfgDatasets = configs['datasets']['visual_dataset']['movifex']

# More Variables
datasetName = cfgDatasets['name']
jsonFilePath = cfgDatasets['path_metadata']

# %% [markdown]
# **Test I. Loading the Corresponding Dataset Metadata**
#
# - ⚙️ Function: `loadJsonFromUrl`

# %%
from movifex.utils import loadJsonFromUrl

print(f"- Fetching the list of movies from '{datasetName}' dataset ...")
jsonData = loadJsonFromUrl(jsonFilePath)

print(jsonData)
# Out:
# - Fetching the list of movies from 'MoViFex-visual' dataset ...
# [{'id': '0000000006', 'title': 'Heat', 'year': 1995, 'genres': ['Action', 'Crime', 'Thriller']}, {'id': '0000000050', 'title': 'Usual Suspects, The', 'year': 1995, 'genres': ['Crime', 'Mystery', 'Thriller']}, {'id': '0000000111', 'title': 'Taxi Driver', 'year': 1976, 'genres': ['Crime', 'Drama', 'Thriller']}, {'id': '0000000150', 'title': 'Apollo 13', 'year': 1995, 'genres': ['Adventure', 'Drama', 'IMAX']}, {'id': '0000000165', 'title': 'Die Hard: With a Vengeance', 'year': 1995, 'genres': ['Action', 'Crime', 'Thriller']}, {'id': '0000000231', 'title': 'Dumb & Dumber (Dumb and Dumber)', 'year': 1994, 'genres': ['Adventure', 'Comedy']}, {'id': '0000000266', 'title': 'Legends of the Fall', 'year': 1994, 'genres': ['Drama', 'Romance', 'War', 'Western']}, {'id': '0000000293', 'title': 'LÃ©on: The Professional (a.k.a. The Professional) (LÃ©on)', 'year': 1994, 'genres': ['Action', 'Crime', 'Drama', 'Thriller']}, {'id': '0000000296', 'title': 'Pulp Fiction', 'year': 1994, 'genres': ['Comedy', 'Crime', 'Drama', 'Thriller']}, {'id': '0000000318', 'title': 'Shawshank Redemption, The', 'year': 1994, 'genres': ['Crime', 'Drama']}, {'id': '0000000356', 'title': 'Forrest Gump', 'year': 1994, 'genres': ['Comedy', 'Drama', 'Romance', 'War']}, {'id': '0000000420', 'title': 'Beverly Hills Cop III', 'year': 1994, 'genres': ['Action', 'Comedy', 'Crime', 'Thriller']}, {'id': '0000000480', 'title': 'Jurassic Park', 'year': 1993, 'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']}, {'id': '0000000527', 'title': "Schindler's List", 'year': 1993, 'genres': ['Drama', 'War']}, {'id': '0000000553', 'title': 'Tombstone', 'year': 1993, 'genres': ['Action', 'Drama', 'Western']}, {'id': '0000000586', 'title': 'Home Alone', 'year': 1990, 'genres': ['Children', 'Comedy']}, {'id': '0000000589', 'title': 'Terminator 2: Judgment Day', 'year': 1991, 'genres': ['Action', 'Sci-Fi']}, {'id': '0000000608', 'title': 'Fargo', 'year': 1996, 'genres': ['Comedy', 'Crime', 'Drama', 'Thriller']}, {'id': '0000000778', 'title': 'Trainspotting', 'year': 1996, 'genres': ['Comedy', 'Crime', 'Drama']}, {'id': '0000000858', 'title': 'Godfather, The', 'year': 1972, 'genres': ['Crime', 'Drama']}, {'id': '0000000904', 'title': 'Rear Window', 'year': 1954, 'genres': ['Mystery', 'Thriller']}, {'id': '0000000912', 'title': 'Casablanca', 'year': 1942, 'genres': ['Drama', 'Romance']}, {'id': '0000001036', 'title': 'Die Hard', 'year': 1988, 'genres': ['Action', 'Crime', 'Thriller']}, {'id': '0000001089', 'title': 'Reservoir Dogs', 'year': 1992, 'genres': ['Crime', 'Mystery', 'Thriller']}, {'id': '0000001193', 'title': "One Flew Over the Cuckoo's Nest", 'year': 1975, 'genres': ['Drama']}, {'id': '0000001200', 'title': 'Aliens', 'year': 1986, 'genres': ['Action', 'Adventure', 'Horror', 'Sci-Fi']}, {'id': '0000001201', 'title': 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il)', 'year': 1966, 'genres': ['Action', 'Adventure', 'Western']}, {'id': '0000001203', 'title': '12 Angry Men', 'year': 1957, 'genres': ['Drama']}, {'id': '0000001206', 'title': 'Clockwork Orange, A', 'year': 1971, 'genres': ['Crime', 'Drama', 'Sci-Fi', 'Thriller']}, {'id': '0000001213', 'title': 'Goodfellas', 'year': 1990, 'genres': ['Crime', 'Drama']}, {'id': '0000001214', 'title': 'Alien', 'year': 1979, 'genres': ['Horror', 'Sci-Fi']}, {'id': '0000001221', 'title': 'Godfather: Part II, The', 'year': 1974, 'genres': ['Crime', 'Drama']}, {'id': '0000001227', 'title': 'Once Upon a Time in America', 'year': 1984, 'genres': ['Crime', 'Drama']}, {'id': '0000001252', 'title': 'Chinatown', 'year': 1974, 'genres': ['Crime', 'Film-Noir', 'Mystery', 'Thriller']}, {'id': '0000001266', 'title': 'Unforgiven', 'year': 1992, 'genres': ['Drama', 'Western']}, {'id': '0000001339', 'title': "Dracula (Bram Stoker's Dracula)", 'year': 1992, 'genres': ['Fantasy', 'Horror', 'Romance', 'Thriller']}, {'id': '0000001370', 'title': 'Die Hard 2', 'year': 1990, 'genres': ['Action', 'Adventure', 'Thriller']}, {'id': '0000001377' ...

# %% [markdown]
# **Test II. Prepare a List of Proper Information for Trailer Finding**
#
# - ⚙️ Function: `filterMovieList`

# %%
from movifex.pipelines.downloaders.utils import filterMovieList

print(f"- Preparing data to make proper queries for movie finding ...")
filteredMovies = filterMovieList(jsonData)

print(filteredMovies)
# Out:
# - Preparing data to make proper queries for movie finding ...
# - Prepared 274 movies data from the JSON data to query YouTube ...
#
# [{'id': '0000000006', 'title': 'Heat', 'year': 1995}, {'id': '0000000050', 'title': 'Usual Suspects, The', 'year': 1995}, {'id': '0000000111', 'title': 'Taxi Driver', 'year': 1976}, {'id': '0000000150', 'title': 'Apollo 13', 'year': 1995}, {'id': '0000000165', 'title': 'Die Hard: With a Vengeance', 'year': 1995}, {'id': '0000000231', 'title': 'Dumb & Dumber (Dumb and Dumber)', 'year': 1994}, {'id': '0000000266', 'title': 'Legends of the Fall', 'year': 1994}, {'id': '0000000293', 'title': 'LÃ©on: The Professional (a.k.a. The Professional) (LÃ©on)', 'year': 1994}, {'id': '0000000296', 'title': 'Pulp Fiction', 'year': 1994}, {'id': '0000000318', 'title': 'Shawshank Redemption, The', 'year': 1994}, {'id': '0000000356', 'title': 'Forrest Gump', 'year': 1994}, {'id': '0000000420', 'title': 'Beverly Hills Cop III', 'year': 1994}, {'id': '0000000480', 'title': 'Jurassic Park', 'year': 1993}, {'id': '0000000527', 'title': "Schindler's List", 'year': 1993}, {'id': '0000000553', 'title': 'Tombstone', 'year': 1993}, {'id': '0000000586', 'title': 'Home Alone', 'year': 1990}, {'id': '0000000589', 'title': 'Terminator 2: Judgment Day', 'year': 1991}, {'id': '0000000608', 'title': 'Fargo', 'year': 1996}, {'id': '0000000778', 'title': 'Trainspotting', 'year': 1996}, {'id': '0000000858', 'title': 'Godfather, The', 'year': 1972}, {'id': '0000000904', 'title': 'Rear Window', 'year': 1954}, {'id': '0000000912', 'title': 'Casablanca', 'year': 1942}, {'id': '0000001036', 'title': 'Die Hard', 'year': 1988}, {'id': '0000001089', 'title': 'Reservoir Dogs', 'year': 1992}, {'id': '0000001193', 'title': "One Flew Over the Cuckoo's Nest", 'year': 1975}, {'id': '0000001200', 'title': 'Aliens', 'year': 1986}, {'id': '0000001201', 'title': 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il)', 'year': 1966}, {'id': '0000001203', 'title': '12 Angry Men', 'year': 1957}, {'id': '0000001206', 'title': 'Clockwork Orange, A', 'year': 1971}, {'id': '0000001213', 'title': 'Goodfellas', 'year': 1990}, {'id': '0000001214', 'title': 'Alien', 'year': 1979}, {'id': '0000001221', 'title': 'Godfather: Part II, The', 'year': 1974}, {'id': '0000001227', 'title': 'Once Upon a Time in America', 'year': 1984}, {'id': '0000001252', 'title': 'Chinatown', 'year': 1974}, {'id': '0000001266', 'title': 'Unforgiven', 'year': 1992}, {'id': '0000001339', 'title': "Dracula (Bram Stoker's Dracula)", 'year': 1992}, {'id': '0000001370', 'title': 'Die Hard 2', 'year': 1990}, {'id': '0000001377', 'title': 'Batman Returns', 'year': 1992}, {'id': '0000001573', 'title': 'Face/Off', 'year': 1997}, {'id': '0000001584', 'title': 'Contact', 'year': 1997}, {'id': '0000001619', 'title': 'Seven Years in Tibet', 'year': 1997}, {'id': '0000001645', 'title': "The Devil's Advocate", 'year': 1997}, {'id': '0000001690', 'title': 'Alien: Resurrection', 'year': 1997}, {'id': '0000001704', 'title': 'Good Will Hunting', 'year': 1997}, {'id': '0000001721', 'title': 'Titanic', 'year': 1997}, {'id': '0000001954', 'title': 'Rocky', 'year': 1976}, {'id': '0000001961', 'title': 'Rain Man', 'year': 1988}, {'id': '0000001997', 'title': 'Exorcist, The', 'year': 1973}, {'id': '0000002011', 'title': 'Back to the Future Part II', 'year': 1989}, {'id': '0000002023', 'title': 'Godfather: Part III, The', 'year': 1990}, {'id': '0000002028', 'title': 'Saving Private Ryan', 'year': 1998}, {'id': '0000002167', 'title': 'Blade', 'year': 1998}, {'id': '0000002329', 'title': 'American History X', 'year': 1998}, {'id': '0000002409', 'title': 'Rocky II', 'year': 1979}, {'id': '0000002410', 'title': 'Rocky III', 'year': 1982}, {'id': '0000002411', 'title': 'Rocky IV', 'year': 1985}, {'id': '0000002571', 'title': 'Matrix, The', 'year': 1999}, {'id': '0000002959', 'title': 'Fight Club', 'year': 1999}, {'id': '0000003147', 'title': 'Green Mile, The', 'year': 1999}, {'id': '0000003178', 'title': 'Hurricane, The', 'year': 1999}, {'id': '0000003198', 'title': 'Papillon', 'year': 1973}, {'id': '0000003362', 'title': 'Dog Day Afte ...

# %% [markdown]
# **Test III. Search and Download the Trailers**
#
# - ⚙️ Function: `downloadMovieTrailers`

# %%
from movifex.pipelines.downloaders.movieTrailerDownloader import downloadMovieTrailers

# Sampling (optional)
filteredMovies = filteredMovies[:3]

downloadMovieTrailers(cfgPipeline, filteredMovies)
# Out:
# - Running the Trailer-fetcher ...
# -- Generating the YouTube links for the given movies ...
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['movieRenderer'])
# WARNING:pytube.contrib.search:Search term: Heat trailer (1995)
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['reelShelfRenderer'])
# WARNING:pytube.contrib.search:Search term: Heat trailer (1995)
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['movieRenderer'])
# WARNING:pytube.contrib.search:Search term: Usual Suspects, The trailer (1995)
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['reelShelfRenderer'])
# WARNING:pytube.contrib.search:Search term: Usual Suspects, The trailer (1995)
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['reelShelfRenderer'])
# WARNING:pytube.contrib.search:Search term: Usual Suspects, The trailer (1995)
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['movieRenderer'])
# WARNING:pytube.contrib.search:Search term: Taxi Driver trailer (1976)
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['reelShelfRenderer'])
# WARNING:pytube.contrib.search:Search term: Taxi Driver trailer (1976)
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# -- Generated 3 YouTube links for the movies!
#
# - Downloading the results in / ...
# - Downloading the trailer of 'Heat' from https://youtube.com/watch?v=14oNcFxiVaQ ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-9-86f4dfd0b045> in <cell line: 0>()
#       4 filteredMovies = filteredMovies[:3]
#       5
# ----> 6 downloadMovieTrailers(cfgPipeline, filteredMovies)
#
# /content/MoViFex/movifex/pipelines/downloaders/movieTrailerDownloader.py in downloadMovieTrailers(configs, filteredMovies)
#      74         if trailer['link']:
#      75             # Download the trailer
# ---> 76             YouTube(trailer['link']).streams.first().download(output_path=configs['download_path'], filename=f"{trailer['id']}")
#      77             print(f"- Downloaded the trailer of '{trailer['title']}'!\n")
#      78         else:
#
# /usr/local/lib/python3.11/dist-packages/pytube/__main__.py in streams(self)
#     294         """
#     295         self.check_availability()
# --> 296         return StreamQuery(self.fmt_streams)
#     297
#     298     @property
#
# /usr/local/lib/python3.11/dist-packages/pytube/__main__.py in fmt_streams(self)
#     174         self._fmt_streams = []
#     175
# --> 176         stream_manifest = extract.apply_descrambler(self.streaming_data)
#     177
#     178         # If the cached js doesn't work, try fetching a new js file
#
# /usr/local/lib/python3.11/dist-packages/pytube/__main__.py in streaming_data(self)
#     158             return self.vid_info['streamingData']
#     159         else:
# --> 160             self.bypass_age_gate()
#     161             return self.vid_info['streamingData']
#     162
#
# /usr/local/lib/python3.11/dist-packages/pytube/__main__.py in bypass_age_gate(self)
#     255             allow_cache=self.allow_oauth_cache
#     256         )
# --> 257         innertube_response = innertube.player(self.video_id)
#     258
#     259         playability_status = innertube_response['playabilityStatus'].get('status', None)
#
# /usr/local/lib/python3.11/dist-packages/pytube/innertube.py in player(self, video_id)
#     446         }
#     447         query.update(self.base_params)
# --> 448         return self._call_api(endpoint, query, self.base_data)
#     449
#     450     def search(self, search_query, continuation=None):
#
# /usr/local/lib/python3.11/dist-packages/pytube/innertube.py in _call_api(self, endpoint, query, data)
#     388         headers.update(self.header)
#     389
# --> 390         response = request._execute_request(
#     391             endpoint_url,
#     392             'POST',
#
# /usr/local/lib/python3.11/dist-packages/pytube/request.py in _execute_request(url, method, headers, data, timeout)
#      35     else:
#      36         raise ValueError("Invalid URL")
# ---> 37     return urlopen(request, timeout=timeout)  # nosec
#      38
#      39
#
# /usr/lib/python3.11/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.11/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.11/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.11/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.11/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.11/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden
